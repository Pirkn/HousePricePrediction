# %% [markdown]
# # House Price Prediction

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
import scipy
from scipy.special import boxcox1p
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from sklearn.preprocessing import StandardScaler
from pycaret.regression import setup, compare_models

from sklearn.linear_model import BayesianRidge, OrthogonalMatchingPursuit
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor


import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
test_ids = test_df["Id"]

# %%
train_ids = train_df["Id"]
target = train_df["SalePrice"]

df = pd.concat([train_df, test_df], axis=0)
df.reset_index(inplace=True)
df = df.drop(["SalePrice", "index", "Id"], axis=1)

# %% [markdown]
# ## Proper DTypes

# %%
df["MSSubClass"] = df["MSSubClass"].astype(str)

# %% [markdown]
# ## Handle Missing Values

# %%
df.select_dtypes("object").loc[:, df.isna().sum() > 0].columns
# Out:
# Index(['MSZoning', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PoolQC', 'Fence', 'MiscFeature', 'SaleType'],
#       dtype='object')

# %% [markdown]
# #### Impute Categorical Columns

# %%
# NAN Means Something
for column in ["Alley", "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "FireplaceQu", "GarageType",
     "GarageFinish", "GarageQual", "GarageCond", "PoolQC", "Fence", "MiscFeature"
]:
    df[column] = df[column].fillna("None")

# NAN Doesn`t mean something
for column in ["MSZoning", "Utilities", "Exterior1st", "Exterior2nd", "Electrical", "KitchenQual", "Functional", "SaleType",
     "MasVnrType"
]:
    df[column] = df[column].fillna(df[column].mode()[0])

# %%
missing_columns = {}
for column in df.columns:
    if df[column].isna().sum() > 0:
        missing_columns[column] = [df[column].isna().sum(), df[column].dtype]

# %%
df.select_dtypes(np.number).loc[:, df.isna().sum() > 0].columns
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %% [markdown]
# #### Impute Numerical Columns

# %%
imputer = KNNImputer(n_neighbors = 5)
numeric_df = df.select_dtypes(np.number)

# %%
imputed_df = imputer.fit_transform(numeric_df)
imputed_df = pd.DataFrame(imputed_df, index=numeric_df.index, columns=numeric_df.columns)

# %%
imputed_cols = numeric_df.columns
for col in imputed_cols:
    df[col] = imputed_df[col]

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Feature Transformation

# %% [markdown]
# #### Skewed Numeric Features Transformation

# %%
df.select_dtypes(np.number).describe()
# Out:
#        LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  2919.000000    2919.000000  2919.000000  2919.000000  2919.000000
# mean     69.994519   10168.114080     6.089072     5.564577  1971.312778
# std      22.588230    7886.996359     1.409947     1.113131    30.291442
# min      21.000000    1300.000000     1.000000     1.000000  1872.000000
# 25%      60.000000    7478.000000     5.000000     5.000000  1953.500000
# 50%      70.000000    9453.000000     6.000000     5.000000  1973.000000
# 75%      80.000000   11570.000000     7.000000     6.000000  2001.000000
# max     313.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   2919.000000  2919.000000  2919.000000  2919.000000  2919.000000  ...
# mean    1984.264474   102.456389   441.300240    49.576841   560.845152  ...
# std       20.894344   178.918648   455.581216   169.176867   439.486058  ...
# min     1950.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     1965.000000     0.000000     0.000000     0.000000   220.000000  ...
# 50%     1993.000000     0.000000   368.000000     0.000000   467.000000  ...
# 75%     2004.000000   165.000000   733.000000     0.000000   805.000000  ...
# max     2010.000000  1600.000000  5644.000000  1526.000000  2336.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  2919.000000  2919.000000  2919.000000    2919.000000  2919.000000
# mean    472.897568    93.709832    47.486811      23.098321     2.602261
# std     215.361488   126.526589    67.575493      64.244246    25.188169
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     320.000000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    26.000000       0.000000     0.000000
# 75%     576.000000   168.000000    70.000000       0.000000     0.000000
# max    1488.000000  1424.000000   742.000000    1012.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  2919.000000  2919.000000   2919.000000  2919.000000  2919.000000
# mean     16.062350     2.251799     50.825968     6.213087  2007.792737
# std      56.184365    35.663946    567.402211     2.714762     1.314964
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
# [8 rows x 35 columns]

# %%
skew_df = pd.DataFrame(df.select_dtypes(np.number).columns, columns=["Feature"])
skew_df["Skew"] =  skew_df["Feature"].apply(lambda feature: abs(scipy.stats.skew(df[feature])))
skew_df["Skewed"] = skew_df["Skew"] > 0.4

# %%
skew_df
# Out:
#           Feature       Skew  Skewed
# 0     LotFrontage   1.353444    True
# 1         LotArea  12.822431    True
# 2     OverallQual   0.197110   False
# 3     OverallCond   0.570312    True
# 4       YearBuilt   0.599806    True
# 5    YearRemodAdd   0.451020    True
# 6      MasVnrArea   2.597595    True
# 7      BsmtFinSF1   1.425421    True
# 8      BsmtFinSF2   4.146111    True
# 9       BsmtUnfSF   0.918938    True
# 10    TotalBsmtSF   1.162763    True
# 11       1stFlrSF   1.469604    True
# 12       2ndFlrSF   0.861675    True
# 13   LowQualFinSF  12.088761    True
# 14      GrLivArea   1.269358    True
# 15   BsmtFullBath   0.624451    True
# 16   BsmtHalfBath   3.931594    True
# 17       FullBath   0.167606   False
# 18       HalfBath   0.694566    True
# 19   BedroomAbvGr   0.326324   False
# 20   KitchenAbvGr   4.302254    True
# 21   TotRmsAbvGrd   0.758367    True
# 22     Fireplaces   0.733495    True
# 23    GarageYrBlt   0.317420   False
# 24     GarageCars   0.218593   False
# 25     GarageArea   0.240896   False
# 26     WoodDeckSF   1.842433    True
# 27    OpenPorchSF   2.535114    True
# 28  EnclosedPorch   4.003891    True
# 29      3SsnPorch  11.376065    True
# 30    ScreenPorch   3.946694    True
# 31       PoolArea  16.898328    True
# 32        MiscVal  21.947195    True
# 33         MoSold   0.195884   False
# 34         YrSold   0.132399   False

# %%
skewed_cols = skew_df[skew_df["Skewed"] == True]["Feature"].values
lam = 0.15
for col in skewed_cols:
    df[col] = boxcox1p(df[col], lam)

# %% [markdown]
# #### Categorical Features Transformation

# %%
df = pd.get_dummies(df)

# %% [markdown]
# #### Target Transformation

# %%
boxcox_target, lam = boxcox(target)
boxcox_target = pd.Series(boxcox_target)
boxcox_target.name = "SalePrice"

# %% [markdown]
# #### Scale Data

# %%
scaler = StandardScaler()
df = pd.DataFrame(scaler.fit_transform(df), index=df.index, columns=df.columns)
df.head()
# Out:
#    LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0    -0.085180 -0.142360     0.646183    -0.449532   1.041483      0.895888
# 1     0.536508  0.110415    -0.063185     1.957283   0.160515     -0.391011
# 2     0.048143  0.431443     0.646183    -0.449532   0.976573      0.848489
# 3    -0.319292  0.099975     0.646183    -0.449532  -1.868103     -0.679016
# 4     0.685631  0.925808     1.355551    -0.449532   0.944098      0.753630
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_ConLw  \
# 0    1.165548    0.800175   -0.358469  -0.548233  ...       -0.052423
# 1   -0.789452    0.974354   -0.358469  -0.132447  ...       -0.052423
# 2    1.065461    0.610875   -0.358469   0.167138  ...       -0.052423
# 3   -0.789452    0.234987   -0.358469   0.329226  ...       -0.052423
# 4    1.488837    0.761300   -0.358469   0.256492  ...       -0.052423
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# 0     -0.298629     -0.049029     0.394439              -0.263861
# 1     -0.298629     -0.049029     0.394439              -0.263861
# 2     -0.298629     -0.049029     0.394439              -0.263861
# 3     -0.298629     -0.049029     0.394439               3.789876
# 4     -0.298629     -0.049029     0.394439              -0.263861
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0              -0.064249              -0.09105             -0.126535
# 1              -0.064249              -0.09105             -0.126535
# 2              -0.064249              -0.09105             -0.126535
# 3              -0.064249              -0.09105             -0.126535
# 4              -0.064249              -0.09105             -0.126535
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0              0.463937              -0.302693
# 1              0.463937              -0.302693
# 2              0.463937              -0.302693
# 3             -2.155466              -0.302693
# 4              0.463937              -0.302693
#
# [5 rows x 317 columns]

# %% [markdown]
# ## Split Data

# %%
train = df.iloc[:len(train_df), :].copy()
test = df.iloc[len(train_df):, :].copy()

# %% [markdown]
# ## Compare Models

# %%
_ = setup(data=pd.concat([train, boxcox_target], axis=1), target="SalePrice")
# Out:
# <style type="text/css">
# #T_a5ab8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5ab8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5ab8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5ab8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5ab8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5ab8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a5ab8_row0_col1" class="data row0 col1" >1147</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5ab8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5ab8_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5ab8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a5ab8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5ab8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a5ab8_row3_col1" class="data row3 col1" >(1460, 318)</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5ab8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a5ab8_row4_col1" class="data row4 col1" >(1460, 318)</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5ab8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a5ab8_row5_col1" class="data row5 col1" >(1021, 318)</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5ab8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a5ab8_row6_col1" class="data row6 col1" >(439, 318)</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5ab8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a5ab8_row7_col1" class="data row7 col1" >317</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a5ab8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a5ab8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a5ab8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a5ab8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a5ab8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a5ab8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a5ab8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a5ab8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a5ab8_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_a5ab8_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a5ab8_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_a5ab8_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a5ab8_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_a5ab8_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a5ab8_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_a5ab8_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a5ab8_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_a5ab8_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a5ab8_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_a5ab8_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a5ab8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a5ab8_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_a5ab8_row18_col1" class="data row18 col1" >759a</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f402c th {
#   text-align: left;
# }
# #T_f402c_row0_col0, #T_f402c_row0_col1, #T_f402c_row0_col6, #T_f402c_row1_col0, #T_f402c_row1_col1, #T_f402c_row1_col2, #T_f402c_row1_col3, #T_f402c_row1_col4, #T_f402c_row1_col5, #T_f402c_row1_col6, #T_f402c_row2_col0, #T_f402c_row2_col2, #T_f402c_row2_col3, #T_f402c_row2_col4, #T_f402c_row2_col5, #T_f402c_row3_col0, #T_f402c_row3_col1, #T_f402c_row3_col2, #T_f402c_row3_col3, #T_f402c_row3_col4, #T_f402c_row3_col5, #T_f402c_row3_col6, #T_f402c_row4_col0, #T_f402c_row4_col1, #T_f402c_row4_col2, #T_f402c_row4_col3, #T_f402c_row4_col4, #T_f402c_row4_col5, #T_f402c_row4_col6, #T_f402c_row5_col0, #T_f402c_row5_col1, #T_f402c_row5_col2, #T_f402c_row5_col3, #T_f402c_row5_col4, #T_f402c_row5_col5, #T_f402c_row5_col6, #T_f402c_row6_col0, #T_f402c_row6_col1, #T_f402c_row6_col2, #T_f402c_row6_col3, #T_f402c_row6_col4, #T_f402c_row6_col5, #T_f402c_row6_col6, #T_f402c_row7_col0, #T_f402c_row7_col1, #T_f402c_row7_col2, #T_f402c_row7_col3, #T_f402c_row7_col4, #T_f402c_row7_col5, #T_f402c_row7_col6, #T_f402c_row8_col0, #T_f402c_row8_col1, #T_f402c_row8_col2, #T_f402c_row8_col3, #T_f402c_row8_col4, #T_f402c_row8_col5, #T_f402c_row8_col6, #T_f402c_row9_col0, #T_f402c_row9_col1, #T_f402c_row9_col2, #T_f402c_row9_col3, #T_f402c_row9_col4, #T_f402c_row9_col5, #T_f402c_row9_col6, #T_f402c_row10_col0, #T_f402c_row10_col1, #T_f402c_row10_col2, #T_f402c_row10_col3, #T_f402c_row10_col4, #T_f402c_row10_col5, #T_f402c_row10_col6, #T_f402c_row11_col0, #T_f402c_row11_col1, #T_f402c_row11_col2, #T_f402c_row11_col3, #T_f402c_row11_col4, #T_f402c_row11_col5, #T_f402c_row11_col6, #T_f402c_row12_col0, #T_f402c_row12_col1, #T_f402c_row12_col2, #T_f402c_row12_col3, #T_f402c_row12_col4, #T_f402c_row12_col5, #T_f402c_row12_col6, #T_f402c_row13_col0, #T_f402c_row13_col1, #T_f402c_row13_col2, #T_f402c_row13_col3, #T_f402c_row13_col4, #T_f402c_row13_col5, #T_f402c_row13_col6, #T_f402c_row14_col0, #T_f402c_row14_col1, #T_f402c_row14_col2, #T_f402c_row14_col3, #T_f402c_row14_col4, #T_f402c_row14_col5, #T_f402c_row14_col6, #T_f402c_row15_col0, #T_f402c_row15_col1, #T_f402c_row15_col2, #T_f402c_row15_col3, #T_f402c_row15_col4, #T_f402c_row15_col5, #T_f402c_row15_col6, #T_f402c_row16_col0, #T_f402c_row16_col1, #T_f402c_row16_col2, #T_f402c_row16_col3, #T_f402c_row16_col4, #T_f402c_row16_col5, #T_f402c_row16_col6 {
#   text-align: left;
# }
# #T_f402c_row0_col2, #T_f402c_row0_col3, #T_f402c_row0_col4, #T_f402c_row0_col5, #T_f402c_row2_col1, #T_f402c_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f402c_row0_col7, #T_f402c_row1_col7, #T_f402c_row2_col7, #T_f402c_row3_col7, #T_f402c_row4_col7, #T_f402c_row5_col7, #T_f402c_row6_col7, #T_f402c_row7_col7, #T_f402c_row8_col7, #T_f402c_row9_col7, #T_f402c_row10_col7, #T_f402c_row11_col7, #T_f402c_row12_col7, #T_f402c_row14_col7, #T_f402c_row15_col7, #T_f402c_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f402c_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f402c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f402c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f402c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f402c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f402c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f402c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f402c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f402c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f402c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f402c_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_f402c_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f402c_row0_col1" class="data row0 col1" >0.0349</td>
#       <td id="T_f402c_row0_col2" class="data row0 col2" >0.0027</td>
#       <td id="T_f402c_row0_col3" class="data row0 col3" >0.0510</td>
#       <td id="T_f402c_row0_col4" class="data row0 col4" >0.8891</td>
#       <td id="T_f402c_row0_col5" class="data row0 col5" >0.0058</td>
#       <td id="T_f402c_row0_col6" class="data row0 col6" >0.0045</td>
#       <td id="T_f402c_row0_col7" class="data row0 col7" >0.1090</td>
#     </tr>
#     <tr>
#       <th id="T_f402c_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_f402c_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f402c_row1_col1" class="data row1 col1" >0.0367</td>
#       <td id="T_f402c_row1_col2" class="data row1 col2" >0.0029</td>
#       <td id="T_f402c_row1_col3" class="data row1 col3" >0.0537</td>
#       <td id="T_f402c_row1_col4" class="data row1 col4" >0.8782</td>
#       <td id="T_f402c_row1_col5" class="data row1 col5" >0.0061</td>
#       <td id="T_f402c_row1_col6" class="data row1 col6" >0.0047</td>
#       <td id="T_f402c_row1_col7" class="data row1 col7" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_f402c_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_f402c_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_f402c_row2_col1" class="data row2 col1" >0.0345</td>
#       <td id="T_f402c_row2_col2" class="data row2 col2" >0.0032</td>
#       <td id="T_f402c_row2_col3" class="data row2 col3" >0.0552</td>
#       <td id="T_f402c_row2_col4" class="data row2 col4" >0.8667</td>
#       <td id="T_f402c_row2_col5" class="data row2 col5" >0.0063</td>
#       <td id="T_f402c_row2_col6" class="data row2 col6" >0.0044</td>
#       <td id="T_f402c_row2_col7" class="data row2 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_f402c_level0_row3" class="row_heading level0 row3" >omp</th>
#       <td id="T_f402c_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_f402c_row3_col1" class="data row3 col1" >0.0355</td>
#       <td id="T_f402c_row3_col2" class="data row3 col2" >0.0033</td>
#       <td id="T_f402c_row3_col3" class="data row3 col3" >0.0557</td>
#       <td id="T_f402c_row3_col4" class="data row3 col4" >0.8622</td>
#       <td id="T_f402c_row3_col5" class="data row3 col5" >0.0063</td>
#       <td id="T_f402c_row3_col6" class="data row3 col6" >0.0045</td>
#       <td id="T_f402c_row3_col7" class="data row3 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_f402c_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_f402c_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_f402c_row4_col1" class="data row4 col1" >0.0386</td>
#       <td id="T_f402c_row4_col2" class="data row4 col2" >0.0034</td>
#       <td id="T_f402c_row4_col3" class="data row4 col3" >0.0572</td>
#       <td id="T_f402c_row4_col4" class="data row4 col4" >0.8609</td>
#       <td id="T_f402c_row4_col5" class="data row4 col5" >0.0065</td>
#       <td id="T_f402c_row4_col6" class="data row4 col6" >0.0049</td>
#       <td id="T_f402c_row4_col7" class="data row4 col7" >0.2780</td>
#     </tr>
#     <tr>
#       <th id="T_f402c_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_f402c_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_f402c_row5_col1" class="data row5 col1" >0.0395</td>
#       <td id="T_f402c_row5_col2" class="data row5 col2" >0.0035</td>
#       <td id="T_f402c_row5_col3" class="data row5 col3" >0.0584</td>
#       <td id="T_f402c_row5_col4" class="data row5 col4" >0.8544</td>
#       <td id="T_f402c_row5_col5" class="data row5 col5" >0.0067</td>
#       <td id="T_f402c_row5_col6" class="data row5 col6" >0.0051</td>
#       <td id="T_f402c_row5_col7" class="data row5 col7" >0.2470</td>
#     </tr>
#     <tr>
#       <th id="T_f402c_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_f402c_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_f402c_row6_col1" class="
# GradientBoostingRegressor(random_state=1147)

# %%
models = {
    "br" : BayesianRidge(alpha_1 = 0.010685598696613362,
                         alpha_2 = 0.047812312259566246,
                         lambda_1 = 0.04543456004541208,
                         lambda_2 = 6.1054020906826185e-06),
    "gbr" : GradientBoostingRegressor(),
    "lgbm" : LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11),
    
    "omp" : OrthogonalMatchingPursuit()
}

# %%
for name, model in models.items():
    model.fit(train, boxcox_target)
    print(f"{name} Trained")
# Out:
# br Trained
# gbr Trained
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1769
# [LightGBM] [Info] Number of data points in the train set: 1460, number of used features: 261
# [LightGBM] [Info] Start training from score 7.842252
# lgbm Trained
# omp Trained

# %%
# Make predictions with each model
br_predictions = models["br"].predict(test)
omp_predictions = models["omp"].predict(test)
gbr_predictions = models["gbr"].predict(test)
lgbm_predictions = models["lgbm"].predict(test)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5

# %%
# Apply inverse Box-Cox transformation to each model's predictions
br_pred_transformed = inv_boxcox(br_predictions, lam)
omp_pred_transformed = inv_boxcox(omp_predictions, lam)
gbr_pred_transformed = inv_boxcox(gbr_predictions, lam)
lgbm_pred_transformed = inv_boxcox(lgbm_predictions, lam)

# %%
# Combine the predictions with weights
final_predictions = (
    0.3 * br_pred_transformed +
    0.3 * omp_pred_transformed +
    0.2 * gbr_pred_transformed +
    0.2 * lgbm_pred_transformed
)

# %%
submission = pd.concat([test_ids, pd.Series(final_predictions, name="SalePrice")], axis=1)
submission["Id"] = submission["Id"].astype("Int32")
submission
# Out:
#         Id      SalePrice
# 0     1461  123520.549213
# 1     1462  159145.344312
# 2     1463  185880.568079
# 3     1464  197728.654812
# 4     1465  195883.014634
# ...    ...            ...
# 1454  2915   85873.041328
# 1455  2916   84382.360956
# 1456  2917  168115.999744
# 1457  2918  120024.563200
# 1458  2919  226871.956834
#
# [1459 rows x 2 columns]

# %%
submission.to_csv("submission001.csv", index=False,  header=1)
